# %% [markdown]
# # Mushroom Dataset

# %% [markdown]
# ## Librerie

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Download del dataset

# %% [markdown]
# Importiamo il dataset dalla [repository GitHub](https://github.com/rirolli/Mushroom/blob/master/mushroom_data_all.csv) in cui è stato salvato:

# %%
url = 'https://raw.githubusercontent.com/rirolli/Mushroom/master/mushroom_data_all.csv'
mushroom_data = pd.read_csv(url)

# %%
# Stampa delle prime 5 righe del dataset
mushroom_data.head()
# Out:
#   class_edible cap-shape cap-surface  ... spore-print-color population habitat
# 0            p         x           s  ...                 k          s       u
# 1            e         x           s  ...                 n          n       g
# 2            e         b           s  ...                 n          n       m
# 3            p         x           y  ...                 k          s       u
# 4            e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Ottimizzazione del dataset

# %% [markdown]
# Preparazione dei dati rendendoli tutti in forma numerica in quanto il modello della rete neurale di tensorflow esegui calcoli sui numeri e non sulle stringhe:

# %%
for elem in mushroom_data:
  mushroom_data[elem] = (pd.Categorical(mushroom_data[elem])).codes

# %%
# Stampa delle prime 5 righe del dataset codificato
mushroom_data.head()
# Out:
#    class_edible  cap-shape  cap-surface  ...  spore-print-color  population  habitat
# 0             1          5            2  ...                  2           3        5
# 1             0          5            2  ...                  3           2        1
# 2             0          0            2  ...                  3           2        3
# 3             1          5            3  ...                  2           3        5
# 4             0          5            2  ...                  3           0        1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Ripartizione del dataset

# %% [markdown]
# Si esegue lo Split del dataset per ricavare i dati di test e di valutazione:

# %%
# Il dataset viene diviso il due parti:
# y che contiene solo la colonna 'class_edible'
# X che contiene tutte le altre colonne.
y = mushroom_data.class_edible
X = mushroom_data.drop(labels=['class_edible'],axis=1)

num_inputs = X.shape[1]

# Il dataset viene nuovamente diviso in altre parti:
# train_X e train_y che sono le parti usate per l'addestramento;
# val_X e val_y che contengono le parti per la valutazione della rete;
# test_X e test_y per effettuare le predizioni e assicurarsi il corretto
# funzionamento. 
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=.2)
train_X, test_X, train_y, test_y = train_test_split(train_X, train_y, test_size=.1)

# %% [markdown]
# ## La rete neurale

# %% [markdown]
# Il modello utilizzato è formato da 3 layer totalmente connessi e viene utilizzato come algoritmo di ottimizzazione l'adam:

# %%
model = keras.Sequential([
  tf.keras.layers.Dense(128, input_dim=num_inputs, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(1)
])

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_69 (Dense)             (None, 128)               2944
# _________________________________________________________________
# dense_70 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_71 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 19,585
# Trainable params: 19,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Addestramento della rete neurale

# %% [markdown]
# Ora è il momento di addestrare il modello tramite i dati di train:

# %%
# Creazione del dataset di train
train_dataset = (tf.data.Dataset.from_tensor_slices((train_X.values, train_y.values))).shuffle(len(train_X)).batch(1)

# Addestramento della rete neurale
model.fit(train_dataset, epochs=30)
# Out:
# Epoch 1/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.1227 - accuracy: 0.9480
# Epoch 2/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0252 - accuracy: 0.9901
# Epoch 3/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0211 - accuracy: 0.9935
# Epoch 4/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0133 - accuracy: 0.9952
# Epoch 5/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0148 - accuracy: 0.9950
# Epoch 6/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0198 - accuracy: 0.9952
# Epoch 7/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0186 - accuracy: 0.9949
# Epoch 8/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0129 - accuracy: 0.9966
# Epoch 9/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 10/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0119 - accuracy: 0.9969
# Epoch 11/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0111 - accuracy: 0.9981
# Epoch 12/30
# 5849/5849 [==============================] - 9s 1ms/step - loss: 8.1597e-06 - accuracy: 1.0000
# Epoch 13/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0097 - accuracy: 0.9983
# Epoch 14/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 15/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0090 - accuracy: 0.9983
# Epoch 16/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 1.7369e-05 - accuracy: 1.0000
# Epoch 17/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 5.9266e-07 - accuracy: 1.0000
# Epoch 18/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0213 - accuracy: 0.9962
# Epoch 19/30
# 5849/5849 [==============================] - 10s 2ms/step - loss: 0.0105 - accuracy: 0.9979
# Epoch 20/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0055 - accuracy: 0.9991
# Epoch 21/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0144 - accuracy: 0.9974
# Epoch 22/30
# 5849/5849 [==============================] - 9s 1ms/step - loss: 1.7491e-05 - accuracy: 1.0000
# Epoch 23/30
# 5849/5849 [==============================] - 10s 2ms/step - loss: 0.0102 - accuracy: 0.9986
# Epoch 24/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0137 - accuracy: 0.9985
# Epoch 25/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 9.4047e-05 - accuracy: 1.0000
# Epoch 26/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0166 - accuracy: 0.9983
# Epoch 27/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 8.8939e-07 - accuracy: 1.0000
# Epoch 28/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 4.5631e-08 - accuracy: 1.0000
# Epoch 29/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0190 - accuracy: 0.9983
# Epoch 30/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 2.0186e-07 - accuracy: 1.0000

# %% [markdown]
# ### Valutazione della rete neurale

# %% [markdown]
# Eseguiamo la valutazione del modello:

# %%
# Creazione del dataset di valutazione
val_dataset = (tf.data.Dataset.from_tensor_slices((val_X.values, val_y.values))).shuffle(len(val_X)).batch(1)

# Valutazione del modello
val_loss, val_acc = model.evaluate(val_dataset)
print("\nTest accuracy: {:.2f} ({:.2%})".format(test_acc, test_acc))
# Out:
# 1625/1625 [==============================] - 2s 1ms/step - loss: 8.0953e-08 - accuracy: 1.0000
#
# Test accuracy: 1.00 (100.00%)

# %% [markdown]
# ### Predizione tramite la rete neurale

# %% [markdown]
# Ora è il momento di predire i valori di val_X tramite l'addestramento appena effettuato:

# %%
# Creazione del dataset di predizione
test_dataset = (tf.data.Dataset.from_tensor_slices(test_X.values)).batch(1)

#Predizione del modello
predictions = model.predict(test_dataset)

# %% [markdown]
# Effettuiamo una breve stampa dei valori ottenuti tramite `predict` e degli effettivi valori di `val_y`. Qui vengono mostrati anche il valore di accuratezza della predizione:

# %%
# Modifichiamo i valori ottenuti con la rete in
# modo da renderli più chiari.
predictions_rounded = tf.round(tf.sigmoid(predictions)).numpy()

# Eseguiamo la stampa dei valori 'predictions_rounded' ottenuti tramite
# la predizione, confrontandoli con le etichette reali 'val_y'.
r=0
f=0
for test, pred in zip(test_y, list(predictions_rounded)):
  if test==pred[0]:
    print(f"{test}\t{pred[0]}\t", "Velenoso" if bool(pred[0]) else "Commestibile")
    r+=1
  else:
    print(f"{test}\t{pred[0]}\t", "PREDIZIONE ERRATA")
    f+=1

print(f"\n - Totale predizioni corrette: {r}\n - Totale predizioni errate: {f}\n - Accuratezza predizione: {(r/len(predictions_rounded))*100}")
print(f"\n - Totale funghi velenosi: {np.count_nonzero(predictions_rounded==0)}\n - Totale funghi commestibili: {np.count_nonzero(predictions_rounded==1)}")
# Out:
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
# 0	0.0	 Commestibile
# 1	1.0	 Velenoso
# 1	1.0	 Velenoso
#
#  - Totale predizioni corrette: 650
#  - Totale predizioni errate: 0
#  - Accuratezza predizione: 100.0
#
#  - Totale funghi velenosi: 336
#  - Totale funghi commestibili: 314

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# Tramite i valori trovati generiamo una `confuion_matrix`:

# %%
print(confusion_matrix(test_y, predictions_rounded, normalize=None))
# Out:
# [[336   0]
#  [  0 314]]
