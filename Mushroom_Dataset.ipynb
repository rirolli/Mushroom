# %% [markdown]
# # Mushroom Dataset

# %% [markdown]
# ## Librerie

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sl

from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score


print(tf.__version__)
print(pd.__version__)
print(np.__version__)
print(sl.__version__)
# Out:
# 2.2.0
# 1.0.4
# 1.18.4
# 0.22.2.post1

# %% [markdown]
# ## Download del dataset

# %% [markdown]
# Importiamo il dataset dalla [repository GitHub](https://github.com/rirolli/Mushroom/blob/master/mushroom_data_all.csv) in cui è stato salvato:

# %%
url = 'https://raw.githubusercontent.com/rirolli/Mushroom/master/mushroom_data_all.csv'

mushroom_data = pd.read_csv(url)

# %%
# Stampa delle prime 5 righe del dataset
mushroom_data.head()
# Out:
#   class_edible cap-shape cap-surface  ... spore-print-color population habitat
# 0            p         x           s  ...                 k          s       u
# 1            e         x           s  ...                 n          n       g
# 2            e         b           s  ...                 n          n       m
# 3            p         x           y  ...                 k          s       u
# 4            e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Ottimizzazione del dataset

# %% [markdown]
# Preparazione dei dati rendendoli tutti in forma numerica in quanto il modello della rete neurale di tensorflow esegue calcoli solo su numeri e non sulle stringhe:

# %%
for elem in mushroom_data:
  mushroom_data[elem] = (pd.Categorical(mushroom_data[elem])).codes

# %%
# Stampa delle prime 5 righe del dataset codificato
mushroom_data.head()
# Out:
#    class_edible  cap-shape  cap-surface  ...  spore-print-color  population  habitat
# 0             1          5            2  ...                  2           3        5
# 1             0          5            2  ...                  3           2        1
# 2             0          0            2  ...                  3           2        3
# 3             1          5            3  ...                  2           3        5
# 4             0          5            2  ...                  3           0        1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Ripartizione del dataset

# %% [markdown]
# Si esegue lo Split del dataset per ricavare i dati di test e di valutazione:

# %%
# Il dataset viene diviso il due parti:
# y che contiene solo la colonna 'class_edible'
# X che contiene tutte le altre colonne.
y = mushroom_data.class_edible
X = mushroom_data.drop(labels=['class_edible'],axis=1)

# Il dataset viene nuovamente diviso in altre parti:
# train_X e train_y che sono le parti usate per l'addestramento;
# val_X e val_y che contengono le parti per la valutazione della rete;
# test_X e test_y per effettuare le predizioni e assicurarsi il corretto
# funzionamento. 
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=.2)
train_X, test_X, train_y, test_y = train_test_split(train_X, train_y, test_size=.1)

# I dati vengono poi memorizzati dentro un Dataset di Tensorflow per sfruttarli
# per l'addestramento. Questa stessa operazione viene poi fatta anche per il
# test set e per l'evaluetion set.
train_dataset = (tf.data.Dataset.from_tensor_slices((train_X.values, train_y.values))).shuffle(len(train_X)).batch(1)
val_dataset = (tf.data.Dataset.from_tensor_slices((val_X.values, val_y.values))).shuffle(len(val_X)).batch(1)
test_dataset = (tf.data.Dataset.from_tensor_slices(test_X.values)).batch(1)

# %% [markdown]
# ## La rete neurale

# %% [markdown]
# Il modello utilizzato è formato da 3 layer totalmente connessi e viene utilizzato come algoritmo di ottimizzazione l'adam:

# %%
num_inputs = X.shape[1]

# %%
model = keras.Sequential([
  tf.keras.layers.Dense(128, input_dim=num_inputs, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(1)
])

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               2944
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 19,585
# Trainable params: 19,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Addestramento della rete neurale

# %% [markdown]
# Ora è il momento di addestrare il modello tramite i dati di train:

# %%
# Addestramento della rete neurale
model.fit(train_dataset, epochs=30)
# Out:
# Epoch 1/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.1188 - accuracy: 0.9525
# Epoch 2/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0253 - accuracy: 0.9899
# Epoch 3/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0177 - accuracy: 0.9954
# Epoch 4/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0170 - accuracy: 0.9957
# Epoch 5/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0159 - accuracy: 0.9944
# Epoch 6/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 6.1709e-05 - accuracy: 1.0000
# Epoch 7/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0193 - accuracy: 0.9954
# Epoch 8/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0127 - accuracy: 0.9969
# Epoch 9/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0144 - accuracy: 0.9968
# Epoch 10/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0117 - accuracy: 0.9978
# Epoch 11/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0056 - accuracy: 0.9976
# Epoch 12/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0055 - accuracy: 0.9988
# Epoch 13/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 14/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0086 - accuracy: 0.9983
# Epoch 15/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0127 - accuracy: 0.9979
# Epoch 16/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0202 - accuracy: 0.9962
# Epoch 17/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 18/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 19/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0117 - accuracy: 0.9974
# Epoch 20/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 21/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 2.7966e-05 - accuracy: 1.0000
# Epoch 22/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0242 - accuracy: 0.9978
# Epoch 23/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 24/30
# 5849/5849 [==============================] - 9s 1ms/step - loss: 3.6741e-07 - accuracy: 1.0000
# Epoch 25/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 3.4159e-08 - accuracy: 1.0000
# Epoch 26/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0146 - accuracy: 0.9983
# Epoch 27/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 8.8388e-05 - accuracy: 1.0000
# Epoch 28/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0090 - accuracy: 0.9986
# Epoch 29/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 1.0969e-04 - accuracy: 1.0000
# Epoch 30/30
# 5849/5849 [==============================] - 8s 1ms/step - loss: 0.0204 - accuracy: 0.9991

# %% [markdown]
# ## Valutazione della rete neurale

# %% [markdown]
# Eseguiamo la valutazione del modello:

# %%
# Valutazione del modello
val_loss, val_acc = model.evaluate(val_dataset)
print("\nTest accuracy: {:.2f} ({:.2%})".format(val_acc, val_acc))
# Out:
# 1625/1625 [==============================] - 2s 975us/step - loss: 1.0007e-06 - accuracy: 1.0000
#
# Test accuracy: 1.00 (100.00%)

# %% [markdown]
# ## Predizione tramite la rete neurale

# %% [markdown]
# Ora è il momento di predire i valori del dataset di test tramite l'addestramento appena effettuato:

# %%
# Predizione dei dati tramite il modello
predictions = model.predict(test_dataset)

# %% [markdown]
# Effettuiamo una breve stampa dei valori ottenuti tramite `predict` e degli effettivi valori di `val_y`. Qui vengono mostrato anche il valore di accuratezza della predizione:

# %%
predictions_rounded = tf.round(tf.sigmoid(predictions)).numpy()

# %%
r=0
f=0

# Eseguiamo la stampa dei valori 'predictions' ottenuti tramite
# la predizione con la rete neurale e delle etichette reali 'val_y'.
print("Label \t Prediction \t Description\n")
for test, pred in zip(test_y, tf.sigmoid(predictions).numpy()):
  message = "{}\t{:.2%}".format(test, pred[0])
  if test==np.round(pred[0]):
    r+=1
  else:
    message += "\t PREDIZIONE ERRATA"
    f+=1
  print(message)

print(f"\n - Totale predizioni corrette: {r}\n - Totale predizioni errate: {f}")
print(" - Accuracy prediction: {}".format(accuracy_score(test_y, predictions_rounded)))
# Out:
# Label 	 Prediction 	 Description
#
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.02%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.01%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.20%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 1	100.00%
# 0	0.00%
# 0	0.00%
# 0	0.00%
#
#  - Totale predizioni corrette: 650
#  - Totale predizioni errate: 0
#  - Accuracy prediction: 1.0

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# Tramite i valori ottenuti è possibile generare una `confuion_matrix`:

# %%
predictions_rounded = tf.round(tf.sigmoid(predictions)).numpy()

# %%
print(confusion_matrix(test_y, predictions_rounded, normalize=None))
# Out:
# [[356   0]
#  [  0 294]]
