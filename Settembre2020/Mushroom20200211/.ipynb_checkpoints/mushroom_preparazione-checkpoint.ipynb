# %% [markdown]
# # Mushroom

# %%
import pandas as pd
import sklearn as sl
import numpy as np

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Caricamento del dataset

# %% [markdown]
# Caricamento del dataset mushroom_data_all.csv da utilizzare per addestrare il modello di intelligenza artificiale.

# %%
url = 'mushroom_data_all.csv'

app_data = pd.read_csv(url, na_values=np.nan)

# %%
app_data.head(15)
# Out:
#    class_edible cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0             p         x           s         n       t    p               f
# 1             e         x           s         y       t    a               f
# 2             e         b           s         w       t    l               f
# 3             p         x           y         w       t    p               f
# 4             e         x           s         g       f    n               f
# 5             e         x           y         y       t    a               f
# 6             e         b           s         w       t    a               f
# 7             e         b           y         w       t    l               f
# 8             p         x           y         w       t    p               f
# 9             e         b           s         y       t    a               f
# 10            e         x           y         y       t    l               f
# ...

# %% [markdown]
# ## Split del dataset

# %% [markdown]
# Dividiamo il dataset in tre parti: Train, Validation e Test

# %%
# Dividiamo il dataset in tre parti: Train,
# Validation e Test.
train, test = train_test_split(app_data, test_size=.2)
train, validation = train_test_split(train, test_size=.2)

# %% [markdown]
# Saviamo i dataset appena creati in file csv

# %%
train.to_csv('train.csv', index=False)
validation.to_csv('validation.csv', index=False)
test.to_csv('test.csv', index=False)
